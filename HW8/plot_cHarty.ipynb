# %% [markdown]
# <a href="https://colab.research.google.com/github/cath19/DSPS_cHarty/blob/master/HW8/plot_cHarty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Catherine Harty
#
# HW8
#
# PHYS467

# %%
import pylab as pl
import numpy as np
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive/dsps'
# Out:
# /content/drive/My Drive/dsps

# %%
#Get data
#!wget https://www.kaggle.com/neuromusic/avocado-prices#avocado.csv

# %%
# !unzip 'avocado.csv.zip'
# Out:
# Archive:  avocado.csv.zip
#   inflating: avocado.csv

# %%
#read to data
avocado = pd.read_csv("avocado.csv", sep=",")

# %%
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
avocado.shape
# Out:
# (18249, 14)

# %%
#Analyzing Atlanta, Philadelphia, Denver, Chicago
avocado['Unnamed: 0'] = range(0,18249)
avocado.index = range(0,18249)
avocado.dropna();

# %%
dateTime = []  #create empty array

for i in range(18249):
  #print(avocado['Date'][j])
  stringDateTime = avocado['Date'][i] 
  #print(stringDateTime)
  dateTime.append(pd.to_datetime(stringDateTime, yearfirst = True, format = '%Y/%m/%d', errors='ignore'))

# %%
avocado['datetime'] = dateTime

# %%
avocado.datetime.dtype
# Out:
# dtype('<M8[ns]')

# %%
#Only want dates from 2016 and up
avocado = avocado[avocado['datetime'] > '2016-01-01']

# %%
#Analyzing Atlanta, Philadelphia, Denver, Chicago
avoAtlanta = avocado[avocado['region'] == 'Atlanta']
avoPhil = avocado[avocado['region'] == 'Philadelphia']
avoDenver = avocado[avocado['region'] == 'Denver']
avoChicago = avocado[avocado['region'] == 'Chicago']

# %%
ax = figure(figsize(10,10))
pl.plot(avoAtlanta['datetime'], avoAtlanta['AveragePrice'], 'o', alpha = 0.5, ms= 8, label= 'Atlanta',)
pl.plot(avoPhil['datetime'], avoPhil['AveragePrice'], '>', alpha = 0.5, ms = 8, label = 'Philadelphia')
pl.plot(avoDenver['datetime'], avoDenver['AveragePrice'], 's', alpha = 0.5, ms = 8, label = 'Denver')
pl.plot(avoChicago['datetime'], avoChicago['AveragePrice'], 'v', alpha = 0.5, ms = 8, label = 'Chicago')

pl.xticks(fontsize = 15)
pl.yticks(fontsize = 15)

pl.legend(fontsize = 15)
pl.xlabel('Date', fontsize = 15)
pl.ylabel('Price ($)', fontsize = 15)
pl.title('Avocado Prices [2016 - 2018]', fontsize = 18)

pl.gcf().autofmt_xdate()

# %% [markdown]
# **Plot**: A plot that shows to changes in avocado prices over time. The data is from Atlanta, GA (blue), Philadelphia, PA (orange), Denver, CO (green), and Chicago, IL (red). This plot uses the default colors.
